# %% [markdown]
# import numpy as np
# import pandas as pd
# import os
# import tensorflow as tf
# from keras.preprocessing.image import ImageDataGenerator, load_img
# from keras.layers import Conv2D, Dense, BatchNormalization, Activation, Dropout, MaxPooling2D, Flatten
# from keras.optimizers import Adam, RMSprop, SGD
# from keras import regularizers
# from keras.callbacks import ModelCheckpoint, CSVLogger, TensorBoard, EarlyStopping, ReduceLROnPlateau
# import datetime
# import matplotlib.pyplot as plt
# from keras.utils import plot_model

# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv2D, Dense, BatchNormalization, Activation, Dropout, MaxPooling2D, Flatten
from keras.optimizers import Adam, RMSprop, SGD
from keras import regularizers
from keras.callbacks import ModelCheckpoint, CSVLogger, TensorBoard, EarlyStopping, ReduceLROnPlateau
import datetime
import matplotlib.pyplot as plt
from keras.utils import plot_model

# %%
train_dir = '../input/fer2013/train/'
test_dir = '../input/fer2013/test/'

row, col = 48, 48
classes = 7

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_dir, 'train')
test_count = count_exp(test_dir, 'test')
print(train_count)
print(test_count)
# Out:
#        surprise  fear  angry  neutral   sad  disgust  happy
# train      3171  4097   3995     4965  4830      436   7215
#       surprise  fear  angry  neutral   sad  disgust  happy
# test       831  1024    958     1233  1247      111   1774

# %%
train_count.transpose().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
test_count.transpose().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.3,
                                   horizontal_flip=True)

training_set = train_datagen.flow_from_directory(train_dir,
                                                batch_size=64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory(test_dir,
                                                batch_size=64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
def get_model(input_size, classes=7):
     #Initialising the CNN
    model = tf.keras.models.Sequential()   

    model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape =input_size))
    model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(2, 2))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01)))
    model.add(Conv2D(256, kernel_size=(3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.5))
    
    model.add(Dense(classes, activation='softmax'))

    #Compliling the model
    model.compile(optimizer=Adam(lr=0.0001, decay=1e-6), 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])
    return model

# %%
fernet = get_model((row,col,1), classes)
fernet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        18496
#
#  batch_normalization (BatchN  (None, 48, 48, 64)       256
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 64)       0
#  )
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 22, 22, 256)       295168
#
#  batch_normalization_1 (Batc  (None, 22, 22, 256)      1024
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 11, 11, 256)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 11, 11, 256)       0
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 1024)              31720448
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 32,116,743
# Trainable params: 32,116,103
# Non-trainable params: 640
# _________________________________________________________________
# /opt/conda/lib/python3.7/site-packages/keras/optimizers/optimizer_v2/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
chk_path = 'model.h5'
log_dir = "checkpoint/logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

checkpoint = ModelCheckpoint(filepath=chk_path,
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             moniter='val_loss')

earlystop = EarlyStopping(monitor='val_loss', 
                          min_delta=0, 
                          patience=3, 
                          verbose=1, 
                          restore_best_weights=True)
                        
reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                              factor=0.2, 
                              patience=6, 
                              verbose=1, 
                              min_delta=0.0001)


tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
csv_logger = CSVLogger('training.log')

callbacks = [checkpoint, reduce_lr, csv_logger]

# %%
steps_per_epoch = training_set.n // training_set.batch_size
validation_steps = test_set.n // test_set.batch_size

hist = fernet.fit(x=training_set,
                 validation_data=test_set,
                 epochs=60,
                 callbacks=callbacks,
                 steps_per_epoch=steps_per_epoch,
                 validation_steps=validation_steps)
# Out:
# Epoch 1/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7058 - accuracy: 0.7719
# Epoch 1: val_loss did not improve from 1.06171
# 448/448 [==============================] - 47s 105ms/step - loss: 0.7058 - accuracy: 0.7719 - val_loss: 1.0742 - val_accuracy: 0.6553 - lr: 6.4000e-09
# Epoch 2/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6989 - accuracy: 0.7747
# Epoch 2: val_loss did not improve from 1.06171
# 448/448 [==============================] - 49s 109ms/step - loss: 0.6989 - accuracy: 0.7747 - val_loss: 1.0744 - val_accuracy: 0.6553 - lr: 6.4000e-09
# Epoch 3/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6996 - accuracy: 0.7758
# Epoch 3: val_loss did not improve from 1.06171
# 448/448 [==============================] - 42s 93ms/step - loss: 0.6996 - accuracy: 0.7758 - val_loss: 1.0736 - val_accuracy: 0.6550 - lr: 6.4000e-09
# Epoch 4/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7032 - accuracy: 0.7723
# Epoch 4: val_loss did not improve from 1.06171
# 448/448 [==============================] - 41s 92ms/step - loss: 0.7032 - accuracy: 0.7723 - val_loss: 1.0745 - val_accuracy: 0.6551 - lr: 6.4000e-09
# Epoch 5/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7044 - accuracy: 0.7761
# Epoch 5: val_loss did not improve from 1.06171
# 448/448 [==============================] - 41s 91ms/step - loss: 0.7044 - accuracy: 0.7761 - val_loss: 1.0735 - val_accuracy: 0.6553 - lr: 6.4000e-09
# Epoch 6/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7025 - accuracy: 0.7745
# Epoch 6: val_loss did not improve from 1.06171
# 448/448 [==============================] - 46s 102ms/step - loss: 0.7025 - accuracy: 0.7745 - val_loss: 1.0732 - val_accuracy: 0.6549 - lr: 6.4000e-09
# Epoch 7/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7080 - accuracy: 0.7737
# Epoch 7: val_loss did not improve from 1.06171
# 448/448 [==============================] - 52s 117ms/step - loss: 0.7080 - accuracy: 0.7737 - val_loss: 1.0727 - val_accuracy: 0.6550 - lr: 6.4000e-09
# Epoch 8/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7039 - accuracy: 0.7741
# Epoch 8: val_loss did not improve from 1.06171
# 448/448 [==============================] - 46s 102ms/step - loss: 0.7039 - accuracy: 0.7741 - val_loss: 1.0724 - val_accuracy: 0.6543 - lr: 6.4000e-09
# Epoch 9/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7015 - accuracy: 0.7752
# Epoch 9: val_loss did not improve from 1.06171
# 448/448 [==============================] - 42s 93ms/step - loss: 0.7015 - accuracy: 0.7752 - val_loss: 1.0746 - val_accuracy: 0.6550 - lr: 6.4000e-09
# Epoch 10/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7077 - accuracy: 0.7748
# Epoch 10: val_loss did not improve from 1.06171
# 448/448 [==============================] - 44s 97ms/step - loss: 0.7077 - accuracy: 0.7748 - val_loss: 1.0737 - val_accuracy: 0.6549 - lr: 6.4000e-09
# Epoch 11/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7055 - accuracy: 0.7712
# Epoch 11: val_loss did not improve from 1.06171
# 448/448 [==============================] - 41s 93ms/step - loss: 0.7055 - accuracy: 0.7712 - val_loss: 1.0737 - val_accuracy: 0.6547 - lr: 6.4000e-09
# Epoch 12/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7084 - accuracy: 0.7729
# Epoch 12: val_loss did not improve from 1.06171
# 448/448 [==============================] - 42s 93ms/step - loss: 0.7084 - accuracy: 0.7729 - val_loss: 1.0743 - val_accuracy: 0.6544 - lr: 6.4000e-09
# Epoch 13/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7067 - accuracy: 0.7734
# Epoch 13: val_loss did not improve from 1.06171
# 448/448 [==============================] - 41s 92ms/step - loss: 0.7067 - accuracy: 0.7734 - val_loss: 1.0750 - val_accuracy: 0.6550 - lr: 6.4000e-09
# Epoch 14/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6999 - accuracy: 0.7746
# Epoch 14: val_loss did not improve from 1.06171
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.279999928271991e-09.
# 448/448 [==============================] - 42s 93ms/step - loss: 0.6999 - accuracy: 0.7746 - val_loss: 1.0752 - val_accuracy: 0.6546 - lr: 6.4000e-09
# Epoch 15/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7017 - accuracy: 0.7738
# Epoch 15: val_loss did not improve from 1.06171
# 448/448 [==============================] - 61s 137ms/step - loss: 0.7017 - accuracy: 0.7738 - val_loss: 1.0742 - val_accuracy: 0.6551 - lr: 1.2800e-09
# Epoch 16/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7096 - accuracy: 0.7695
# Epoch 16: val_loss did not improve from 1.06171
# 448/448 [==============================] - 66s 145ms/step - loss: 0.7096 - accuracy: 0.7695 - val_loss: 1.0747 - val_accuracy: 0.6544 - lr: 1.2800e-09
# Epoch 17/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7070 - accuracy: 0.7724
# Epoch 17: val_loss did not improve from 1.06171
# 448/448 [==============================] - 82s 183ms/step - loss: 0.7070 - accuracy: 0.7724 - val_loss: 1.0746 - val_accuracy: 0.6549 - lr: 1.2800e-09
# Epoch 18/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7022 - accuracy: 0.7722
# Epoch 18: val_loss did not improve from 1.06171
# 448/448 [==============================] - 69s 155ms/step - loss: 0.7022 - accuracy: 0.7722 - val_loss: 1.0747 - val_accuracy: 0.6551 - lr: 1.2800e-09
# Epoch 19/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7088 - accuracy: 0.7714
# Epoch 19: val_loss did not improve from 1.06171
# 448/448 [==============================] - 49s 110ms/step - loss: 0.7088 - accuracy: 0.7714 - val_loss: 1.0730 - val_accuracy: 0.6556 - lr: 1.2800e-09
# Epoch 20/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7052 - accuracy: 0.7701
# Epoch 20: val_loss did not improve from 1.06171
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 2.55999976772614e-10.
# 448/448 [==============================] - 47s 106ms/step - loss: 0.7052 - accuracy: 0.7701 - val_loss: 1.0739 - val_accuracy: 0.6554 - lr: 1.2800e-09
# Epoch 21/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7119 - accuracy: 0.7687
# Epoch 21: val_loss did not improve from 1.06171
# 448/448 [==============================] - 44s 98ms/step - loss: 0.7119 - accuracy: 0.7687 - val_loss: 1.0739 - val_accuracy: 0.6551 - lr: 2.5600e-10
# Epoch 22/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7047 - accuracy: 0.7703
# Epoch 22: val_loss did not improve from 1.06171
# 448/448 [==============================] - 46s 102ms/step - loss: 0.7047 - accuracy: 0.7703 - val_loss: 1.0744 - val_accuracy: 0.6543 - lr: 2.5600e-10
# Epoch 23/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7026 - accuracy: 0.7723
# Epoch 23: val_loss did not improve from 1.06171
# 448/448 [==============================] - 63s 141ms/step - loss: 0.7026 - accuracy: 0.7723 - val_loss: 1.0753 - val_accuracy: 0.6547 - lr: 2.5600e-10
# Epoch 24/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7046 - accuracy: 0.7717
# Epoch 24: val_loss did not improve from 1.06171
# 448/448 [==============================] - 48s 107ms/step - loss: 0.7046 - accuracy: 0.7717 - val_loss: 1.0742 - val_accuracy: 0.6551 - lr: 2.5600e-10
# Epoch 25/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7065 - accuracy: 0.7712
# Epoch 25: val_loss did not improve from 1.06171
# 448/448 [==============================] - 47s 104ms/step - loss: 0.7065 - accuracy: 0.7712 - val_loss: 1.0752 - val_accuracy: 0.6549 - lr: 2.5600e-10
# Epoch 26/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7051 - accuracy: 0.7701
# Epoch 26: val_loss did not improve from 1.06171
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 5.119999424429978e-11.
# 448/448 [==============================] - 48s 107ms/step - loss: 0.7051 - accuracy: 0.7701 - val_loss: 1.0736 - val_accuracy: 0.6553 - lr: 2.5600e-10
# Epoch 27/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7051 - accuracy: 0.7735
# Epoch 27: val_loss did not improve from 1.06171
# 448/448 [==============================] - 46s 103ms/step - loss: 0.7051 - accuracy: 0.7735 - val_loss: 1.0749 - val_accuracy: 0.6550 - lr: 5.1200e-11
# Epoch 28/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7093 - accuracy: 0.7724
# Epoch 28: val_loss did not improve from 1.06171
# 448/448 [==============================] - 43s 95ms/step - loss: 0.7093 - accuracy: 0.7724 - val_loss: 1.0749 - val_accuracy: 0.6543 - lr: 5.1200e-11
# Epoch 29/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7044 - accuracy: 0.7749
# Epoch 29: val_loss did not improve from 1.06171
# 448/448 [==============================] - 44s 98ms/step - loss: 0.7044 - accuracy: 0.7749 - val_loss: 1.0736 - val_accuracy: 0.6550 - lr: 5.1200e-11
# Epoch 30/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7066 - accuracy: 0.7736
# Epoch 30: val_loss did not improve from 1.06171
# 448/448 [==============================] - 55s 124ms/step - loss: 0.7066 - accuracy: 0.7736 - val_loss: 1.0740 - val_accuracy: 0.6551 - lr: 5.1200e-11
# Epoch 31/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7061 - accuracy: 0.7736
# Epoch 31: val_loss did not improve from 1.06171
# 448/448 [==============================] - 61s 136ms/step - loss: 0.7061 - accuracy: 0.7736 - val_loss: 1.0727 - val_accuracy: 0.6554 - lr: 5.1200e-11
# Epoch 32/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7068 - accuracy: 0.7713
# Epoch 32: val_loss did not improve from 1.06171
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.0239999126415712e-11.
# 448/448 [==============================] - 208s 465ms/step - loss: 0.7068 - accuracy: 0.7713 - val_loss: 1.0752 - val_accuracy: 0.6549 - lr: 5.1200e-11
# Epoch 33/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7036 - accuracy: 0.7733
# Epoch 33: val_loss did not improve from 1.06171
# 448/448 [==============================] - 42s 94ms/step - loss: 0.7036 - accuracy: 0.7733 - val_loss: 1.0750 - val_accuracy: 0.6547 - lr: 1.0240e-11
# Epoch 34/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7047 - accuracy: 0.7714
# Epoch 34: val_loss did not improve from 1.06171
# 448/448 [==============================] - 78s 172ms/step - loss: 0.7047 - accuracy: 0.7714 - val_loss: 1.0748 - val_accuracy: 0.6547 - lr: 1.0240e-11
# Epoch 35/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7015 - accuracy: 0.7726
# Epoch 35: val_loss did not improve from 1.06171
# 448/448 [==============================] - 48s 107ms/step - loss: 0.7015 - accuracy: 0.7726 - val_loss: 1.0743 - val_accuracy: 0.6551 - lr: 1.0240e-11
# Epoch 36/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7048 - accuracy: 0.7700
# Epoch 36: val_loss did not improve from 1.06171
# 448/448 [==============================] - 45s 100ms/step - loss: 0.7048 - accuracy: 0.7700 - val_loss: 1.0736 - val_accuracy: 0.6557 - lr: 1.0240e-11
# Epoch 37/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7037 - accuracy: 0.7721
# Epoch 37: val_loss did not improve from 1.06171
# 448/448 [==============================] - 45s 100ms/step - loss: 0.7037 - accuracy: 0.7721 - val_loss: 1.0744 - val_accuracy: 0.6550 - lr: 1.0240e-11
# Epoch 38/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7108 - accuracy: 0.7697
# Epoch 38: val_loss did not improve from 1.06171
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 2.0479997905886727e-12.
# 448/448 [==============================] - 43s 96ms/step - loss: 0.7108 - accuracy: 0.7697 - val_loss: 1.0738 - val_accuracy: 0.6549 - lr: 1.0240e-11
# Epoch 39/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7021 - accuracy: 0.7725
# Epoch 39: val_loss did not improve from 1.06171
# 448/448 [==============================] - 43s 97ms/step - loss: 0.7021 - accuracy: 0.7725 - val_loss: 1.0747 - val_accuracy: 0.6550 - lr: 2.0480e-12
# Epoch 40/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7058 - accuracy: 0.7732
# Epoch 40: val_loss did not improve from 1.06171
# 448/448 [==============================] - 42s 94ms/step - loss: 0.7058 - accuracy: 0.7732 - val_loss: 1.0751 - val_accuracy: 0.6549 - lr: 2.0480e-12
# Epoch 41/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7070 - accuracy: 0.7722
# Epoch 41: val_loss did not improve from 1.06171
# 448/448 [==============================] - 48s 107ms/step - loss: 0.7070 - accuracy: 0.7722 - val_loss: 1.0738 - val_accuracy: 0.6554 - lr: 2.0480e-12
# Epoch 42/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7090 - accuracy: 0.7691
# Epoch 42: val_loss did not improve from 1.06171
# 448/448 [==============================] - 52s 115ms/step - loss: 0.7090 - accuracy: 0.7691 - val_loss: 1.0740 - val_accuracy: 0.6554 - lr: 2.0480e-12
# Epoch 43/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7011 - accuracy: 0.7742
# Epoch 43: val_loss did not improve from 1.06171
# 448/448 [==============================] - 43s 95ms/step - loss: 0.7011 - accuracy: 0.7742 - val_loss: 1.0742 - val_accuracy: 0.6550 - lr: 2.0480e-12
# Epoch 44/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7095 - accuracy: 0.7709
# Epoch 44: val_loss did not improve from 1.06171
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 4.0959995811773456e-13.
# 448/448 [==============================] - 45s 100ms/step - loss: 0.7095 - accuracy: 0.7709 - val_loss: 1.0746 - val_accuracy: 0.6550 - lr: 2.0480e-12
# Epoch 45/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6975 - accuracy: 0.7752
# Epoch 45: val_loss did not improve from 1.06171
# 448/448 [==============================] - 68s 153ms/step - loss: 0.6975 - accuracy: 0.7752 - val_loss: 1.0746 - val_accuracy: 0.6549 - lr: 4.0960e-13
# Epoch 46/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6994 - accuracy: 0.7741
# Epoch 46: val_loss did not improve from 1.06171
# 448/448 [==============================] - 43s 95ms/step - loss: 0.6994 - accuracy: 0.7741 - val_loss: 1.0742 - val_accuracy: 0.6550 - lr: 4.0960e-13
# Epoch 47/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7063 - accuracy: 0.7741
# Epoch 47: val_loss did not improve from 1.06171
# 448/448 [==============================] - 46s 102ms/step - loss: 0.7063 - accuracy: 0.7741 - val_loss: 1.0749 - val_accuracy: 0.6544 - lr: 4.0960e-13
# Epoch 48/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7015 - accuracy: 0.7723
# Epoch 48: val_loss did not improve from 1.06171
# 448/448 [==============================] - 41s 92ms/step - loss: 0.7015 - accuracy: 0.7723 - val_loss: 1.0741 - val_accuracy: 0.6551 - lr: 4.0960e-13
# Epoch 49/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7113 - accuracy: 0.7711
# Epoch 49: val_loss did not improve from 1.06171
# 448/448 [==============================] - 41s 92ms/step - loss: 0.7113 - accuracy: 0.7711 - val_loss: 1.0740 - val_accuracy: 0.6549 - lr: 4.0960e-13
# Epoch 50/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7059 - accuracy: 0.7743
# Epoch 50: val_loss did not improve from 1.06171
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 8.191999053934474e-14.
# 448/448 [==============================] - 41s 92ms/step - loss: 0.7059 - accuracy: 0.7743 - val_loss: 1.0745 - val_accuracy: 0.6549 - lr: 4.0960e-13
# Epoch 51/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7061 - accuracy: 0.7741
# Epoch 51: val_loss did not improve from 1.06171
# 448/448 [==============================] - 42s 94ms/step - loss: 0.7061 - accuracy: 0.7741 - val_loss: 1.0739 - val_accuracy: 0.6551 - lr: 8.1920e-14
# Epoch 52/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7018 - accuracy: 0.7716
# Epoch 52: val_loss did not improve from 1.06171
# 448/448 [==============================] - 46s 104ms/step - loss: 0.7018 - accuracy: 0.7716 - val_loss: 1.0731 - val_accuracy: 0.6554 - lr: 8.1920e-14
# Epoch 53/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6951 - accuracy: 0.7769
# Epoch 53: val_loss did not improve from 1.06171
# 448/448 [==============================] - 49s 110ms/step - loss: 0.6951 - accuracy: 0.7769 - val_loss: 1.0738 - val_accuracy: 0.6553 - lr: 8.1920e-14
# Epoch 54/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7108 - accuracy: 0.7711
# Epoch 54: val_loss did not improve from 1.06171
# 448/448 [==============================] - 42s 95ms/step - loss: 0.7108 - accuracy: 0.7711 - val_loss: 1.0732 - val_accuracy: 0.6553 - lr: 8.1920e-14
# Epoch 55/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7104 - accuracy: 0.7665
# Epoch 55: val_loss did not improve from 1.06171
# 448/448 [==============================] - 42s 93ms/step - loss: 0.7104 - accuracy: 0.7665 - val_loss: 1.0738 - val_accuracy: 0.6551 - lr: 8.1920e-14
# Epoch 56/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7015 - accuracy: 0.7765
# Epoch 56: val_loss did not improve from 1.06171
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1.638399837891949e-14.
# 448/448 [==============================] - 42s 94ms/step - loss: 0.7015 - accuracy: 0.7765 - val_loss: 1.0748 - val_accuracy: 0.6551 - lr: 8.1920e-14
# Epoch 57/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6979 - accuracy: 0.7763
# Epoch 57: val_loss did not improve from 1.06171
# 448/448 [==============================] - 51s 115ms/step - loss: 0.6979 - accuracy: 0.7763 - val_loss: 1.0735 - val_accuracy: 0.6550 - lr: 1.6384e-14
# Epoch 58/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7078 - accuracy: 0.7741
# Epoch 58: val_loss did not improve from 1.06171
# 448/448 [==============================] - 42s 93ms/step - loss: 0.7078 - accuracy: 0.7741 - val_loss: 1.0747 - val_accuracy: 0.6553 - lr: 1.6384e-14
# Epoch 59/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7090 - accuracy: 0.7709
# Epoch 59: val_loss did not improve from 1.06171
# 448/448 [==============================] - 47s 106ms/step - loss: 0.7090 - accuracy: 0.7709 - val_loss: 1.0746 - val_accuracy: 0.6546 - lr: 1.6384e-14
# Epoch 60/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7065 - accuracy: 0.7731
# Epoch 60: val_loss did not improve from 1.06171
# 448/448 [==============================] - 49s 109ms/step - loss: 0.7065 - accuracy: 0.7731 - val_loss: 1.0733 - val_accuracy: 0.6554 - lr: 1.6384e-14

# %%
plt.figure(figsize=(14,5))
plt.subplot(1,2,2)
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['train', 'test'], loc='upper left')

plt.subplot(1,2,1)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
train_loss, train_accu = fernet.evaluate(training_set)
test_loss, test_accu = fernet.evaluate(test_set)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_accu*100, test_accu*150))
# Out:
# 449/449 [==============================] - 35s 77ms/step - loss: 0.5506 - accuracy: 0.8451
# 113/113 [==============================] - 6s 53ms/step - loss: 1.0738 - accuracy: 0.6551
# final train accuracy = 84.51 , validation accuracy = 98.26

# %%
fernet.save_weights('model1.h5')
